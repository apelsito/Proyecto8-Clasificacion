# %%
# Para la codificación de las variables numéricas
# -----------------------------------------------------------------------
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, LabelEncoder # para poder aplicar los métodos de OneHot, Ordinal,  Label y Target Encoder 
from category_encoders import TargetEncoder

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd

# Tratamiento de datos
# -----------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append("../../")
from src.soporte_graficas import (
    boxplot_scaler
)

import pickle

# %%
df = pd.read_pickle("../../datos/03_datos_encoded.plk")
df["Attrition"] = df["Attrition"].astype(int)

# %% [markdown]
# # Cuales escalar
# - Todas las no binarias

# %% [markdown]
# # Aplicamos Feature Scaling... Pero ¿Cual?
# Tenemos los Siguientes pero antes:
#
# ### ¿Qué importancia tienen los outliers?
# - **RobustScaler:** Es el mas "amigable" con los outliers,genera un rango de 0 a X (depende de cuantos datos tengamos) donde aún manteniendo la distribución los tenemos más juntos, si queremos darles mucho peso es nuestra mejor opción
#
# - **StandardScaler:** También es amigable con los outliers, pero genera un rango de 0 a X mucho menos que el anterior, mantiene la distribución, si queremos darles algo de peso a los outliers, este es definitivamente nuestro amigo.
#
# - **MinMaxScaler:** Genera un rango de 0 a 1 donde mantiene la distribución original pero está todo mucho más comprimido, aquí los outliers no se van a poder apreciar, así que si no te interesan y tus datos no están normalizados... es tu opción
#
# - **Normalizer:** Tus datos están normalizados y no te interesan los outliers?, Está es tu opción, Genera un Rango de -1 a 1 en donde mantiene la distribución (como el resto). Es solo para datos normalizados, algo que veremos poco por aquí...

# %% [markdown]
# # Robust Scaler

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1491 entries, 0 to 1490
# Data columns (total 95 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1491 non-null   int64
#  1   Attrition                          1491 non-null   int64
#  2   BusinessTravel                     1491 non-null   float64
#  3   Department                         1491 non-null   float64
#  4   EducationField                     1491 non-null   float64
#  5   MaritalStatus                      1491 non-null   float64
#  6   MonthlyIncome                      1491 non-null   int64
#  7   NumCompaniesWorked                 1491 non-null   float64
#  8   TotalWorkingYears                  1491 non-null   int64
#  9   YearsAtCompany                     1491 non-null   int64
#  10  YearsSinceLastPromotion            1491 non-null   int64
#  11  YearsWithCurrManager               1491 non-null   int64
#  12  EnvironmentSatisfaction            1491 non-null   float64
#  13  JobSatisfaction                    1491 non-null   float64
#  14  WorkLifeBalance                    1491 non-null   float64
#  15  DistanceFromHome_1 km              1491 non-null   float64
#  16  DistanceFromHome_10 km             1491 non-null   float64
#  17  DistanceFromHome_11 km             1491 non-null   float64
#  18  DistanceFromHome_12 km             1491 non-null   float64
#  19  DistanceFromHome_13 km             1491 non-null   float64
#  20  DistanceFromHome_14 km             1491 non-null   float64
#  21  DistanceFromHome_15 km             1491 non-null   float64
#  22  DistanceFromHome_16 km             1491 non-null   float64
#  23  DistanceFromHome_17 km             1491 non-null   float64
#  24  DistanceFromHome_18 km             1491 non-null   float64
#  25  DistanceFromHome_19 km             1491 non-null   float64
#  26  DistanceFromHome_2 km              1491 non-null   float64
#  27  DistanceFromHome_20 km             1491 non-null   float64
#  28  DistanceFromHome_21 km             1491 non-null   float64
#  29  DistanceFromHome_22 km             1491 non-null   float64
#  30  DistanceFromHome_23 km             1491 non-null   float64
#  31  DistanceFromHome_24 km             1491 non-null   float64
#  32  DistanceFromHome_25 km             1491 non-null   float64
#  33  DistanceFromHome_26 km             1491 non-null   float64
#  34  DistanceFromHome_27 km             1491 non-null   float64
#  35  DistanceFromHome_28 km             1491 non-null   float64
#  36  DistanceFromHome_29 km             1491 non-null   float64
#  37  DistanceFromHome_3 km              1491 non-null   float64
#  38  DistanceFromHome_4 km              1491 non-null   float64
#  39  DistanceFromHome_5 km              1491 non-null   float64
#  40  DistanceFromHome_6 km              1491 non-null   float64
#  41  DistanceFromHome_7 km              1491 non-null   float64
#  42  DistanceFromHome_8 km              1491 non-null   float64
#  43  DistanceFromHome_9 km              1491 non-null   float64
#  44  Education_Bachelor                 1491 non-null   float64
#  45  Education_Below College            1491 non-null   float64
#  46  Education_College                  1491 non-null   float64
#  47  Education_Doctor                   1491 non-null   float64
#  48  Education_Master                   1491 non-null   float64
#  49  Gender_Female                      1491 non-null   float64
#  50  Gender_Male                        1491 non-null   float64
#  51  JobLevel_Level 1                   1491 non-null   float64
#  52  JobLevel_Level 2                   1491 non-null   float64
#  53  JobLevel_Level 3                   1491 non-null   float64
#  54  JobLevel_Level 4                   1491 non-null   float64
#  55  JobLevel_Level 5                   1491 non-null   float64
#  56  JobRole_Healthcare Representative  1491 non-null   float64
#  57  JobRole_Human Resources            1491 non-null   float64
#  58  JobRole_Laboratory Technician      1491 non-null   float64
#  59  JobRole_Manager                    1491 non-null   float64
#  60  JobRole_Manufacturing Director     1491 non-null   float64
#  61  JobRole_Research Director          1491 non-null   float64
#  62  JobRole_Research Scientist         1491 non-null   float64
#  63  JobRole_Sales Executive            1491 non-null   float64
#  64  JobRole_Sales Representative       1491 non-null   float64
#  65  PercentSalaryHike_11 %             1491 non-null   float64
#  66  PercentSalaryHike_12 %             1491 non-null   float64
#  67  PercentSalaryHike_13 %             1491 non-null   float64
#  68  PercentSalaryHike_14 %             1491 non-null   float64
#  69  PercentSalaryHike_15 %             1491 non-null   float64
#  70  PercentSalaryHike_16 %             1491 non-null   float64
#  71  PercentSalaryHike_17 %             1491 non-null   float64
#  72  PercentSalaryHike_18 %             1491 non-null   float64
#  73  PercentSalaryHike_19 %             1491 non-null   float64
#  74  PercentSalaryHike_20 %             1491 non-null   float64
#  75  PercentSalaryHike_21 %             1491 non-null   float64
#  76  PercentSalaryHike_22 %             1491 non-null   float64
#  77  PercentSalaryHike_23 %             1491 non-null   float64
#  78  PercentSalaryHike_24 %             1491 non-null   float64
#  79  PercentSalaryHike_25 %             1491 non-null   float64
#  80  StockOptionLevel_Level 0           1491 non-null   float64
#  81  StockOptionLevel_Level 1           1491 non-null   float64
#  82  StockOptionLevel_Level 2           1491 non-null   float64
#  83  StockOptionLevel_Level 3           1491 non-null   float64
#  84  TrainingTimesLastYear_0 Times      1491 non-null   float64
#  85  TrainingTimesLastYear_1 Times      1491 non-null   float64
#  86  TrainingTimesLastYear_2 Times      1491 non-null   float64
#  87  TrainingTimesLastYear_3 Times      1491 non-null   float64
#  88  TrainingTimesLastYear_4 Times      1491 non-null   float64
#  89  TrainingTimesLastYear_5 Times      1491 non-null   float64
#  90  TrainingTimesLastYear_6 Times      1491 non-null   float64
#  91  JobInvolvement_High                1491 non-null   float64
#  92  JobInvolvement_Low                 1491 non-null   float64
#  93  JobInvolvement_Medium              1491 non-null   float64
#  94  JobInvolvement_Very High           1491 non-null   float64
# dtypes: float64(88), int64(7)
# memory usage: 1.1 MB

# %%
df.sample()
# Out:
#      Age  Attrition  BusinessTravel  Department  EducationField  \
# 756   39          1         0.07947    0.164271        0.171975
#
#      MaritalStatus  MonthlyIncome  NumCompaniesWorked  TotalWorkingYears  \
# 756       0.270833          43810            0.115646                 11
#
#      YearsAtCompany  ...  TrainingTimesLastYear_1 Times  \
# 756               1  ...                            1.0
#
#      TrainingTimesLastYear_2 Times  TrainingTimesLastYear_3 Times  \
# 756                            0.0                            0.0
#
#      TrainingTimesLastYear_4 Times  TrainingTimesLastYear_5 Times  \
# 756                            0.0                            0.0
#
#      TrainingTimesLastYear_6 Times  JobInvolvement_High  JobInvolvement_Low  \
# 756                            0.0                  0.0                 0.0
#
#      JobInvolvement_Medium  JobInvolvement_Very High
# 756                    1.0                       0.0
#
# [1 rows x 95 columns]

# %%
cols_escalar = ["Age","BusinessTravel", "Department", "EducationField",
                  "MaritalStatus", "MonthlyIncome", "NumCompaniesWorked","TotalWorkingYears",
                  "YearsAtCompany","YearsSinceLastPromotion","YearsWithCurrManager",
                  "EnvironmentSatisfaction", "JobSatisfaction", "WorkLifeBalance"]
escalador_robust = RobustScaler()
datos_transf_robust = escalador_robust.fit_transform(df[cols_escalar])
df_c = pd.DataFrame(datos_transf_robust,columns=df[cols_escalar].columns)
df.drop(columns=cols_escalar, inplace=True)
df = pd.concat([df_c,df],axis=1)

# %%
with open('../../datos/encoders_y_modelos/robust_scaler.pkl', 'wb') as f:
    pickle.dump(escalador_robust, f)

# %%
df.to_pickle("../../datos/04_datos_feature_scaled.plk")
